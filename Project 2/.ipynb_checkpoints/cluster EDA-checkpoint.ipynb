# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('clustered.csv')

# %%
EDA_df = pd.read_csv('EDA.csv')

# %%
df_cluster = pd.DataFrame(df['four_cluster_label'])

# %%
df = pd.concat([EDA_df, df_cluster], axis = 1)

# %%
df.groupby(['four_cluster_label'])['age'].mean()
# Out:
# four_cluster_label
# 0    45.987629
# 1    50.567663
# 2    51.666327
# 3    58.130260
# Name: age, dtype: float64

# %% [markdown]
# 0 and 1 are youngest, followed by 3 and then 1. 3 is Clinton, 1 is Trump.

# %%
df.groupby(['four_cluster_label']).size()
# Out:
# four_cluster_label
# 0     8326
# 1    11875
# 2    12758
# 3    15185
# dtype: int64

# %%
df.groupby(['four_cluster_label'])['faminc'].mean()
# Out:
# four_cluster_label
# 0    58878.479822
# 1    58817.160589
# 2    80162.846920
# 3    73139.293513
# Name: faminc, dtype: float64

# %% [markdown]
# 0 and 2 have similar incomes, both poorer than Trump and Clinton.

# %%
df.groupby(['four_cluster_label', 'stateLE']).size()
# Out:
# four_cluster_label  stateLE
# 0                   Decrease      749
#                     Increase     1180
#                     Maintain     6397
# 1                   Decrease      502
#                     Increase    10065
#                     Maintain     1308
# 2                   Decrease     2178
#                     Increase     3876
#                     Maintain     6704
# 3                   Decrease      720
#                     Increase    11043
#                     Maintain     3422
# dtype: int64

# %% [markdown]
# 0 wants to maintain LE spending, 1 wants to increase it.

# %% [markdown]
# Turn these into plots, obviously

# %%
#function plotting how respondent's answers to a given column, grouped by how they voted for president
def cluster_plot(groupcol, col, df, title = ''):
    cluster_df = df.groupby([groupcol, col]).size() / df.groupby([groupcol]).size()

    cluster_df = cluster_df.to_frame()
    cluster_df = cluster_df.reset_index(level=[0,1])
    cluster_df = cluster_df.pivot(index =groupcol, columns = col, values = 0)
    
    _ = cluster_df.plot(kind = 'bar', rot = 70, figsize = (8,6))
    _ = plt.title(title)
    _ = plt.ylim(0, 1.1)

    plt.show()

# %%
cluster_plot('four_cluster_label', 'race', df, 'race by cluster')

# %% [markdown]
# 3 is overwhelmingly white - 1 is the least white at around 60%.

# %%
cluster_plot('four_cluster_label', 'repealACA', df, 'support for repealing ACA by cluster')

# %% [markdown]
# 0 favors repealing the ACA, 1 is split but is slightly opposed to repealing the ACA.

# %%
cluster_plot('four_cluster_label', 'stateLE', df, '')

# %%
cluster_plot('four_cluster_label', 'stateinfra', df, '')

# %%
cluster_plot('four_cluster_label', 'stateedu', df, '')

# %%
cluster_plot('four_cluster_label', 'statehealthcare', df, '')

# %%
cluster_plot('four_cluster_label', 'statewelfare', df, '')

# %% [markdown]
# It's pretty clear that the state spending questions are a key factor differentiating 0 and 1... is this bias?

# %%
cluster_plot('four_cluster_label', 'ideo5', df, '')

# %% [markdown]
# Ugh the two independent clusters are like the same... spurious differences.

# %%
cluster_plot('four_cluster_label', 'abortion20wks', df, '')

# %% [markdown]
# 0 likes banning abortion more

# %%
cluster_plot('four_cluster_label', 'primary', df, '')

# %% [markdown]
# 2 is much less likely to vote in a primary

# %%
cluster_plot('four_cluster_label', 'stateinfra', df, '')

# %% [markdown]
# 2 loves to maintain infrastructure spending...

# %%
cluster_plot('four_cluster_label', 'college', df, '')

# %% [markdown]
# 3 are hella educated. everyone else not so much

# %%
cluster_plot('four_cluster_label', 'educ', df, '')

# %%
cluster_plot('four_cluster_label', 'EPACO2', df, '')

# %%
cluster_plot('four_cluster_label', 'gaymarriage', df, '')

# %% [markdown]
# 2 is more pro-gay marriage.

# %%
cluster_plot('four_cluster_label', 'stateedu', df, '')

# %% [markdown]
# 2 loves to maintain shit!!!! this might be a source of bias
