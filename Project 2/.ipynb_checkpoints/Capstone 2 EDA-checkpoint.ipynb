# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('EDA.csv')

# %%
for col in df.columns:
    print(col)
# Out:
# Unnamed: 0
# tookpost
# gender
# educ
# race
# legalstatus
# borderpatrol
# legalstatusHS
# deport
# employ
# milstat_1
# milstat_2
# milstat_3
# milstat_4
# minwage12
# faminc
# mandatorymin
# bodycamera
# pew_religimp
# ideo5
# threestrikes
# pew_bornagain
# increasepolice
# cleanair
# marstat
# fuelefficiency
# EPACO2
# abortionchoice
# abortioncoverage
# federalabortion
# renewables
# religpew
# ownhome
# abortion20wks
# repealACA
# banmostabortion
# child18
# TPP
# NCLB
# union
# primary
# immstat
# Iransanctions
# infraspending
# backgroundcheck
# medicarereform
# concealedcarry
# gunregistry
# unionhh
# banassault
# gaymarriage
# hispanic
# sexuality
# investor
# trans
# inputstate_post
# votereg_post
# militaryoil
# militaryterror
# militarycivilwar
# militarydemocracy
# militaryally
# militaryUN
# polmeeting
# polsign
# campaignwork
# campaigndonate
# donateblood
# partyID
# whiteadvantage
# angryracism
# edloan
# racismrare
# fearrace
# statewelfare
# statehealthcare
# ...

# %% [markdown]
# **Distributions of numerical variables**
#
# Let's explore some basic distributions:

# %%
_ = df['age'].plot(kind = 'hist', bins = 20)
_ = plt.title("Distribution of age among survey respondents")
plt.show()

# %%
df['age'].describe()
# Out:
# count    48144.000000
# mean        52.452040
# std         16.137073
# min         20.000000
# 25%         38.000000
# 50%         54.000000
# 75%         65.000000
# max         97.000000
# Name: age, dtype: float64

# %% [markdown]
# Median age is 54, mean is 52. Distribution appears to be possibly bimodal.

# %%
_ = df['faminc'].plot(kind = 'hist', bins = 20)
_ = plt.title("Distribution of family income among survey respondents")
plt.show()

# %% [markdown]
# The family income distribution is right-skewed. Binning bias does appear to be a problem, though, so let's look at the cumulative distribution function as well:

# %%
import numpy as np

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

x, y = ecdf(df['faminc'])

_ = plt.plot(x,y, linestyle = 'none', marker = '.')
_ = plt.xlabel('Family Income')
_ = plt.ylabel('Empirical cumulative distribution function')
plt.show()

# %% [markdown]
# The vast majority of respondents had a family income of under $200,000.

# %%
df['faminc'].describe()
# Out:
# count     48144.000000
# mean      69001.615528
# std       55631.571665
# min        5000.000000
# 25%       34999.000000
# 50%       54999.000000
# 75%       89999.000000
# max      500000.000000
# Name: faminc, dtype: float64

# %% [markdown]
# Median family income was $55,000.

# %% [markdown]
# **Distributions of categorical variables**

# %% [markdown]
# Now, let's look at respondents broken down by their religious beliefs:

# %%
religions = df.groupby(['religpew']).size().sort_values(ascending = False) / df.shape[0]
_ = religions.plot(kind= 'bar', rot = 70)
_ = plt.title("Respondents by religion")
plt.show()

# %% [markdown]
# Protestant is the most common religious view, with over 35% of respondents.

# %%
presidents = df.groupby(['presvote']).size().sort_values(ascending = False) / df.shape[0]
_ = presidents.plot(kind= 'bar', rot = 70)
_ = plt.title("Respondents by presidential vote")
plt.show()

# %% [markdown]
# Hillary Clinton was the most popular vote-getter among this survey, with around 42%, while Trump received around 35% of the vote. Note that this is larger than the actual popular vote margin in the 2016 election (around two points). This means that this survey was not perfectly representative, and the other charts will be also be somewhat skewed towards Clinton.

# %% [markdown]
# **Presidential vote by other features**
#
# Now I will look at how respondents voted based on their characteristics. For simplicity, I will just look at the two major parties (Democratic and Republican). Here is a line graph of two-party vote by age:

# %%
pres_df = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby(['age', 'presvote']).size()
total = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby(['age']).size()
pres_df = pres_df / total
pres_df = pres_df.to_frame()
pres_df = pres_df.reset_index(level=[0,1])
pres_df = pres_df.pivot(index = 'age', columns = 'presvote', values = 0)
    
#pres_df = pres_df.sort_values('Trump')
_ = pres_df.plot(kind = 'line', rot = 0, color = ['b','r'], figsize = (7,5))
_ = plt.title('Two-party vote by age')
_ = plt.ylim(0, 1.1)
_ = plt.xlim(20, 90)

plt.show()

# %% [markdown]
# Trump's share of the two-party vote almost monotonically increases with age.
#
# Next, I show two-party vote by family income:

# %%
pres_df = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby(['faminc', 'presvote']).size()
total = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby(['faminc']).size()
pres_df = pres_df / total
pres_df = pres_df.to_frame()
pres_df = pres_df.reset_index(level=[0,1])
pres_df = pres_df.pivot(index = 'faminc', columns = 'presvote', values = 0)
    
#pres_df = pres_df.sort_values('Trump')
_ = pres_df.plot(kind = 'line', rot = 0, color = ['b','r'], figsize = (7,5))
_ = plt.title('Two-party vote by family income')
_ = plt.ylim(0, 1.1)

plt.show()

# %% [markdown]
# High income and low income households were more likely to support Clinton, while households making close to $50,000 were roughly evenly split.

# %%
#function that plots the proportion of respondents voting for Trump or Clinton, grouped by answers to an inputted column
def pres_plot(col, title = ' ', rotation = 70):
    #Create dataframe showing proportion of respondents voting for either Trump or Clinton
    pres_df = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby([col, 'presvote']).size()
    total = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby([col]).size()
    pres_df = pres_df / total
    pres_df = pres_df.to_frame()
    pres_df = pres_df.reset_index(level=[0,1])
    pres_df = pres_df.pivot(index = col, columns = 'presvote', values = 0)
    
    pres_df = pres_df.sort_values('Trump')
    _ = pres_df.plot(kind = 'bar', rot = rotation, color = ['b','r'], figsize = (7,5))
    _ = plt.title(title)
    _ = plt.ylim(0, 1.1)

    plt.show()

# %%
pres_plot('race', 'Two-party vote by race')

# %% [markdown]
# Black and Asian respondents largely preferred Clinton over Trump, while white respondents were more likely to prefer Trump, and Native American and "Other" respondents were most likely to support Trump. The Native American result surprised me given that other ethnic minorities mostly support Democrats, though a cursory Google search did not turn up information on how Native Americans usually vote. Note that there were only 401 respondents who identified as Native Americans in this dataframe.

# %%
pres_plot('religpew', 'Two-party vote by religion')

# %% [markdown]
# Muslims, Atheists, and Agnostics were most likely to support Clinton. Mormons and Protestants were most likely to support Trump. Roman Catholics were largely split, with a slight edge to Trump.

# %%
pres_plot('marstat', 'Two-party vote by marriage status')

# %% [markdown]
# Single respondents and those in domestic partnerships were most likely to support Clinton, and widowed respondents were most likely to support Trump. This is likely an artifact of age, with single people being younger and widowed people being older.

# %%
pres_plot('employ', 'Two-party vote by employment status')

# %%
pres_plot('educ', 'Two-party vote by educational attainment')

# %% [markdown]
# Support for Clinton over Trump increases as education increases.

# %%
pres_plot('veteran', 'Two-party vote by military service', 0)

# %% [markdown]
# Respondents with military service are more supportive of Trump than those without military service.

# %%
pres_plot('family_vet', 'Two-party vote by family military service', 0)

# %% [markdown]
# Respondents without a family member in the military tend to support Clinton, while those with a family member in the military are about evenly split.

# %%
pres_plot('partyID')

# %% [markdown]
# Not surprisingly, self-identifying Democrats overwhelming support Clinton, and self-identifying Republicans overwhelming support Trump. Independents were somewhat more likely to support Trump than Clinton.

# %%
pres_plot('ideo5')

# %% [markdown]
# Presidential vote by ideology is again not very surprising, though the middle option is somewhat more Democratic.

# %% [markdown]
# **Opinion polling by presidential vote**
#
# Now I will show how respondents responded to questions on political issues, broken down by how they voted for president.

# %%
#function plotting how respondent's answers to a given column, grouped by how they voted for president
def opinion_plot(col, df, title = ''):
    opinion_df = df.groupby(['presvote', col]).size() / df.groupby(['presvote']).size()

    opinion_df = opinion_df.to_frame()
    opinion_df = opinion_df.reset_index(level=[0,1])
    opinion_df = opinion_df.pivot(index ='presvote', columns = col, values = 0)
    #sort dataframe by proportion selecting the second option (1 or Favor)
    opinion_df = opinion_df.sort_values(1)
    #add line showing overall response
    opinion_df.loc['Total'] = [df.groupby([col]).size()[0]/df.shape[0], df.groupby([col]).size()[1]/df.shape[0]]
    
    _ = opinion_df.plot(kind = 'bar', rot = 70, figsize = (6.5,4.5))
    _ = plt.title(title)
    _ = plt.legend(['No', 'Yes'])
    _ = plt.ylim(0, 1.1)

    plt.show()

# %% [markdown]
# The full wording for this question was: "Grant legal status to people who were brought to the US illegally as children, but who have graduated from a U.S. high school"

# %%
opinion_plot('legalstatusHS', df, 'Support for legal status for undocumented immigrants')

# %% [markdown]
# Trump supporters are least likely to support providing legal status to undocumented immigrants, while Clinton voters are most supportive.

# %%
opinion_plot('minwage12', df, 'Support for raising minimum wage to $12 an hour')

# %% [markdown]
# On raising the minimum wage, Clinton voters are the most supportive, while McMullin voters the least supportive, followed by Trump voters.

# %%
opinion_plot('mandatorymin', df, 'Support for eliminating mandatory minimums for non-violent drug offenses')

# %% [markdown]
# For eliminating mandatory minimums, Trump voters take the position that is most "tough on crime", Stein and Clinton
# voters are most likely to support leniency.

# %%
opinion_plot('EPACO2', df, 'Support for allowing the EPA to regulate CO2 emissions')

# %% [markdown]
# On CO2 regulations, Clinton and Stein voters are most supportive, and Trump voters are the least supportive.

# %%
opinion_plot('abortionchoice', df, 'Support for always allowing abortion as a matter of choice')

# %% [markdown]
# On abortion, McMullin voters are by far the least supportive, followed by Trump voters, and Clinton voters are most supportive.

# %%
opinion_plot('banassault', df, 'Support for banning assault rifles')

# %% [markdown]
# On gun control, Clinton voters are the most supportive, and Trump voters are the least supportive.

# %%
opinion_plot('gaymarriage', df, 'Support for allowing gay marriage')

# %% [markdown]
# On gay marriage, Stein and Clinton voters are the most supportive, and McMullin voters are the least supportive, followed by Trump voters.

# %%
opinion_plot('repealACA', df, 'Support for repealing the ACA (Obamacare)')

# %% [markdown]
# On repealing Obamacare, Clinton voters are the most opposed, while Trump voters are the most supportive, followed by McMullin and Johnson voters.

# %% [markdown]
# These plots are largely consistent with conventional wisdom on the political opinions of the various parties. Trump is a conservative Republican, while Clinton is a liberal Democrat; in terms of third parties, Evan McMullin was a socially conservative independent, Gary Johnson was a Libertarian who was generally socially liberal and economically conservative, and Jill Stein was the Green Party nominee with liberal views.
#
# The positions of Johnson/Stein voters was somewhat surprising. Stein voters were less "liberal" than Clinton voters on 6 of the 8 questions, including the question on CO2 emissions, despite my impression that Jill Stein is very liberal and the Green Party is focused on environmental issues. In addition, Johnson voters were more likely to support raising the minimum wage, banning assault rifles, keeping the ACA, and allowing the EPA to regulate CO2 emissions than Trump voters, suggesting that Johnson voters are not all "hard-core" libertarians. One possible explanation is that these third-party candidates attracted voters who are not very ideological and for that reason decided not to vote for one of the two major parties.
#
# For all questions, non-voters and voters who voted for other candidates are somewhere in the middle. Compared to all respondents, non-voters are slightly more liberal on the minimum wage, CO2 regulations, and more conservative than average on immigration.
