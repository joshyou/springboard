# race_Mixed
# race_Native American
# race_Other
# race_White
# college
# PartyID
# Party_Democrat
# Party_Independent
# Party_Republican
# relig_Agnostic
# relig_Atheist
# relig_Buddhist
# relig_Eastern or Greek Orthodox
# relig_Hindu
# relig_Jewish
# relig_Mormon
# relig_Muslim
# relig_Nothing in particular
# relig_Protestant
# relig_Roman Catholic
# relig_Something else
# straight
# immigrant
# union_member
# pres_Clinton
# pres_Johnson
# pres_McMullin
# pres_None
# pres_Other
# pres_Stein
# pres_Trump
# employ_Full-time
# employ_Homemaker
# employ_Other
# employ_Part-time
# employ_Permanently disabled
# employ_Retired
# employ_Student
# employ_Temporarily laid off
# employ_Unemployed
# mar_Divorced
# mar_Domestic partnership
# mar_Married
# mar_Separated
# mar_Single
# mar_Widowed
# religimp_Not at all important
# religimp_Not too important
# religimp_Somewhat important
# religimp_Very important

# %% [markdown]
# Let's explore some basic distributions:

# %%
_ = df['age'].plot(kind = 'hist', bins = 20)
_ = plt.title("Distribution of age among survey respondents")
plt.show()

# %%
df['age'].describe()
# Out:
# count    48125.000000
# mean        52.448623
# std         16.138152
# min         20.000000
# 25%         38.000000
# 50%         54.000000
# 75%         65.000000
# max         97.000000
# Name: age, dtype: float64

# %% [markdown]
# Median age is 54, mean is 52. Distribution appears to be possibly bimodal.

# %%
_ = df['faminc'].plot(kind = 'hist', bins = 20)
_ = plt.title("Distribution of family income among survey respondents")
plt.show()

# %% [markdown]
# pretty right skewed

# %%
religions = df.groupby(['religpew']).size().sort_values(ascending = False) / df.shape[0]
_ = religions.plot(kind= 'bar', rot = 70)
_ = plt.title("Respondents by religion")
plt.show()

# %%
president_vote = df.groupby(['presvote']).size()
president_vote.sort_values(inplace = True, ascending = False)
president_vote = (president_vote / df.shape[0]) * 100
president_vote
# Out:
# presvote
# Clinton     42.514025
# Trump       35.730314
# None        13.985041
# Johnson      3.527945
# Other        2.146271
# Stein        1.766050
# McMullin     0.330355
# dtype: float64

# %% [markdown]
# Break down things by party ID, vote? double bar charts, stacked histograms, etc.

# %%
race_pres = df.loc[(df['presvote'] == 'Trump') 
       | (df['presvote'] == 'Clinton')].groupby(['race', 'presvote']).size()

total = df.loc[(df['presvote'] == 'Trump') 
       | (df['presvote'] == 'Clinton')].groupby(['race']).size()

race_ratio = race_pres / total

# %%
race_ratio
# Out:
# race             presvote
# Asian            Clinton     0.716832
#                  Trump       0.283168
# Black            Clinton     0.931102
#                  Trump       0.068898
# Hispanic         Clinton     0.695813
#                  Trump       0.304187
# Middle Eastern   Clinton     0.716667
#                  Trump       0.283333
# Mixed            Clinton     0.671602
#                  Trump       0.328398
# Native American  Clinton     0.405229
#                  Trump       0.594771
# Other            Clinton     0.319149
#                  Trump       0.680851
# White            Clinton     0.478123
#                  Trump       0.521877
# dtype: float64

# %%
race_ratio = race_ratio.to_frame()

race_ratio
# Out:
#                                  0
# race            presvote
# Asian           Clinton   0.716832
#                 Trump     0.283168
# Black           Clinton   0.931102
#                 Trump     0.068898
# Hispanic        Clinton   0.695813
#                 Trump     0.304187
# Middle Eastern  Clinton   0.716667
#                 Trump     0.283333
# Mixed           Clinton   0.671602
#                 Trump     0.328398
# Native American Clinton   0.405229
#                 Trump     0.594771
# Other           Clinton   0.319149
#                 Trump     0.680851
# White           Clinton   0.478123
#                 Trump     0.521877

# %%
race_ratio = race_ratio.reset_index(level=[0,1])

# %%
race_ratio = race_ratio.pivot(index ='race', columns = 'presvote', values = 0)

race_ratio
# Out:
# presvote          Clinton     Trump
# race
# Asian            0.716832  0.283168
# Black            0.931102  0.068898
# Hispanic         0.695813  0.304187
# Middle Eastern   0.716667  0.283333
# Mixed            0.671602  0.328398
# Native American  0.405229  0.594771
# Other            0.319149  0.680851
# White            0.478123  0.521877

# %%
_ = race_ratio.plot(kind = 'bar', rot = 70, color = ['b','r'])
_ = plt.title('Two-party vote by race')
plt.show()

# %%
relig_pres = df.loc[(df['presvote'] == 'Trump') 
       | (df['presvote'] == 'Clinton')].groupby(['religpew', 'presvote']).size()

relig_total = df.loc[(df['presvote'] == 'Trump') 
       | (df['presvote'] == 'Clinton')].groupby(['religpew']).size()

relig_ratio = relig_pres / relig_total

relig_ratio = relig_ratio.to_frame()
relig_ratio = relig_ratio.reset_index(level=[0,1])
relig_ratio = relig_ratio.pivot(index ='religpew', columns = 'presvote', values = 0)

# %%
_ = relig_ratio.plot(kind = 'bar', rot = 70, color = ['b','r'], figsize = (8,6))
_ = plt.title('Two-party vote by religion')
_ = plt.ylim(0, 1.1)

plt.show()

# %%
def pres_plot(col, title = ' '):
    pres_df = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby([col, 'presvote']).size()
    total = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby([col]).size()
    pres_df = pres_df / total
    
    pres_df = pres_df.to_frame()
    pres_df = pres_df.reset_index(level=[0,1])
    pres_df = pres_df.pivot(index = col, columns = 'presvote', values = 0)
    
    _ = pres_df.plot(kind = 'bar', rot = 70, color = ['b','r'], figsize = (7,5))
    _ = plt.title(title)
    _ = plt.ylim(0, 1.1)

    plt.show()

# %%
pres_plot('marstat', 'Two-party vote by marriage status')

# %%
pres_plot('employ', 'Two-party vote by employment status')

# %%
pres_plot('educ', 'Two-party vote by educational attainment')

# %%
pres_plot('union', 'Two-party vote by union membership')

# %%
pres_plot('milstat', 'Two-party vote by marriage status')
#add this back in
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-f059244e19d9> in <module>()
# ----> 1 pres_plot('milstat', 'Two-party vote by marriage status')
#
# <ipython-input-42-218638330b93> in pres_plot(col, title)
#       1 def pres_plot(col, title = 'hey'):
# ----> 2     pres_df = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby([col, 'presvote']).size()
#       3     total = df.loc[(df['presvote'] == 'Trump') | (df['presvote'] == 'Clinton')].groupby([col]).size()
#       4     pres_df = pres_df / total
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
#    1701
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2688                 in_axis, name, level, gpr = False, None, gpr, None
#    2689             else:
# -> 2690                 raise KeyError(gpr)
#    2691         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2692             # Add key to exclusions
#
# KeyError: 'milstat'

# %% [markdown]
# Opinion polling by pres vote:
#
# CC16_331_7 - deport illegal immigrants
#
# CC16_331_3 - legal status for immigrants who graduate high school, brought as children
#
# milstat - clean this first
#
# CC16_351K - min wage to $12
#
# faminc
#
# CC16_334a - eliminate mandatory minimum for non-violent drug offenses
#
# CC16_333a - EPA - CO2 emissions
#
# CC16_332a - always allow abortion
#
# CC16_330d - assault rifle ban
#
# CC16_335 - support gay marriage
#
# ideology and presidential vote and partisan ID?

# %%
deport = df.groupby(['presvote', 'CC16_331_7']).size() / df.groupby(['presvote']).size()

deport = deport.to_frame()
deport = deport.reset_index(level=[0,1])
deport = deport.pivot(index ='presvote', columns = 'CC16_331_7', values = 0)
deport = deport.sort_values(1)

#add line showing overall response
deport.loc['Total'] = [df.groupby(['CC16_331_7']).size()[0]/df.shape[0], df.groupby(['CC16_331_7']).size()[1]/df.shape[0]]
deport
# Out:
# CC16_331_7         0         1
# presvote
# Clinton     0.817857  0.182143
# Stein       0.769412  0.230588
# Johnson     0.638398  0.361602
# McMullin    0.628931  0.371069
# None        0.581489  0.418511
# Other       0.574056  0.425944
# Trump       0.277781  0.722219
# Total       0.578787  0.421213

# %%
_ = deport.plot(kind = 'bar', rot = 70, figsize = (7,5))
_ = plt.title('Support for deporting illegal immigrants by presidential vote')
_ = plt.legend(['No', 'Yes'])
_ = plt.ylim(0, 1.1)

plt.show()

# %%
def opinion_plot(col, df, title):
    opinion_df = df.groupby(['presvote', col]).size() / df.groupby(['presvote']).size()

    opinion_df = opinion_df.to_frame()
    opinion_df = opinion_df.reset_index(level=[0,1])
    opinion_df = opinion_df.pivot(index ='presvote', columns = col, values = 0)
    #sort dataframe by proportion selecting the second option (1 or Favor)
    opinion_df = opinion_df.sort_values(1)
    #add line showing overall response
    opinion_df.loc['Total'] = [df.groupby([col]).size()[0]/df.shape[0], df.groupby([col]).size()[1]/df.shape[0]]
    
    _ = opinion_df.plot(kind = 'bar', rot = 70, figsize = (6.5,4.5))
    _ = plt.title(title)
    _ = plt.legend(['No', 'Yes'])
    _ = plt.ylim(0, 1.1)

    plt.show()

# %% [markdown]
# Question wording: "What do you think the U.S. government should do about immigration? Select all that apply. Option: Grant legal status to people who were brought to the US illegally as children, but who have graduated from a U.S. high school"

# %% [markdown]
# Could use a standard order for president - make it easier to see trends. But then that would hide the ordering.

# %%
opinion_plot('CC16_331_3', df, 'Support for legal status for undocumented immigrants')
opinion_plot('CC16_351K', df, 'Support for raising minimum wage to $12 an hour')
opinion_plot('CC16_334a', df, 'Support for eliminating mandatory minimums for non-violent drug offenses')
opinion_plot('CC16_333a', df, 'Support for allowing the EPA to regulate CO2 emissions')
opinion_plot('CC16_332a', df, 'Support for always allowing abortion as a matter of choice')
opinion_plot('CC16_330d', df, 'Support for banning assault rifles')
opinion_plot('CC16_335', df, 'Support for allowing gay marriage')
